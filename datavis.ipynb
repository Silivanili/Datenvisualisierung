# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
cols = [
    "AppID","Name","Release date","Estimated owners","Peak CCU","Required age",
    "Price","Discount","DLC count","About the game","Supported languages",
    "Full audio languages","Reviews","Header image","Website","Support url",
    "Support email","Windows","Mac","Linux","Metacritic score","Metacritic url",
    "User score","Positive","Negative","Score rank","Achievements",
    "Recommendations","Notes","Average playtime forever",
    "Average playtime two weeks","Median playtime forever",
    "Median playtime two weeks","Developers","Publishers","Categories",
    "Genres","Tags","Screenshots","Movies"]

df = pd.read_csv("games.csv", header = 0, names = cols)

# %%
df.head()
# Out:
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0    20200       Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370           Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930           Jolt Project  Nov 17, 2021        0 - 20000         0
# 3  1355720               Henosis™  Jul 23, 2020        0 - 20000         0
# 4  1139950  Two Weeks in Painland   Feb 3, 2020        0 - 20000         0
#
#    Required age  Price  Discount  DLC count  \
# 0             0  19.99         0          0
# 1             0   0.99         0          0
# 2             0   4.99         0          0
# 3             0   5.99         0          0
# 4             0   0.00         0          0
#
#                                       About the game  ...  \
# 0  Galactic Bowling is an exaggerated and stylize...  ...
# 1  THE LAW!! Looks to be a showdown atop a train....  ...
# 2  Jolt Project: The army now has a new robotics ...  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111452 entries, 0 to 111451
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       111452 non-null  int64
#  1   Name                        111446 non-null  object
#  2   Release date                111452 non-null  object
#  3   Estimated owners            111452 non-null  object
#  4   Peak CCU                    111452 non-null  int64
#  5   Required age                111452 non-null  int64
#  6   Price                       111452 non-null  float64
#  7   Discount                    111452 non-null  int64
#  8   DLC count                   111452 non-null  int64
#  9   About the game              104969 non-null  object
#  10  Supported languages         111452 non-null  object
#  11  Full audio languages        111452 non-null  object
#  12  Reviews                     10624 non-null   object
# ...

# %%
df.describe()
# Out:
#               AppID      Peak CCU   Required age          Price  \
# count  1.114520e+05  1.114520e+05  111452.000000  111452.000000
# mean   1.716972e+06  1.777215e+02       0.254208       7.061568
# std    9.203859e+05  8.390462e+03       2.035653      12.563246
# min    1.000000e+01  0.000000e+00       0.000000       0.000000
# 25%    9.362550e+05  0.000000e+00       0.000000       0.990000
# 50%    1.665065e+06  0.000000e+00       0.000000       3.990000
# 75%    2.453585e+06  1.000000e+00       0.000000       9.990000
# max    3.671840e+06  1.311366e+06      21.000000     999.980000
#
#             Discount      DLC count  Metacritic score     User score  \
# count  111452.000000  111452.000000     111452.000000  111452.000000
# mean        0.464209       0.449530          2.623354       0.030408
# std         3.503658      12.006677         13.736245       1.565136
# min         0.000000       0.000000          0.000000       0.000000
# ...

# %%
df.hist(figsize=(20, 12))
# Out:
# array([[<Axes: title={'center': 'AppID'}>,
#         <Axes: title={'center': 'Peak CCU'}>,
#         <Axes: title={'center': 'Required age'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Discount'}>,
#         <Axes: title={'center': 'DLC count'}>,
#         <Axes: title={'center': 'Metacritic score'}>,
#         <Axes: title={'center': 'User score'}>],
#        [<Axes: title={'center': 'Positive'}>,
#         <Axes: title={'center': 'Negative'}>,
#         <Axes: title={'center': 'Score rank'}>,
#         <Axes: title={'center': 'Achievements'}>],
#        [<Axes: title={'center': 'Recommendations'}>,
#         <Axes: title={'center': 'Average playtime forever'}>,
#         <Axes: title={'center': 'Average playtime two weeks'}>,
#         <Axes: title={'center': 'Median playtime forever'}>],
#        [<Axes: title={'center': 'Median playtime two weeks'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
plt.boxplot(df.Price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17eaa60c690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17eaa60c910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17eaa60c550>],
#  'medians': [<matplotlib.lines.Line2D at 0x17eaa60cb90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17eaa60ccd0>],
#  'means': []}

# %%
df_clean = df.dropna(subset=["Genres"])
genre_counts = df_clean["Genres"].value_counts().head()
plt.figure(figsize=(12, 7))
plt.bar(genre_counts.index, genre_counts.values)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(x = df['Positive'], y = df['Negative'])

# %%
df_new = df[df['Positive'] <= 900000]

plt.scatter(x = df_new['Positive'], y = df_new['Negative'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


df = df.dropna(subset=['Publishers', 'Average playtime forever'])


avg_plt_per_publ = (
    df.groupby('Publishers')['Average playtime forever']
      .mean()
      .sort_values(ascending=False)          
      .head(10)                               
)


norm = plt.Normalize(vmin=avg_plt_per_publ.min(),
                     vmax=avg_plt_per_publ.max())

cmap = plt.cm.Blues

colours = cmap(norm(avg_plt_per_publ.values))


ax = avg_plt_per_publ.plot(
    kind='barh',
    figsize=(10, 8),
    color=colours,          
    edgecolor='black'       
)

ax.set_xlabel('Average playtime (forever)')
ax.set_title('Average playtime forever per publisher (top 10)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\silva\AppData\Local\Temp\ipykernel_14268\4266876408.py:34: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\silva\AppData\Local\Temp\ipykernel_14268\4266876408.py:34: UserWarning: Glyph 38596 (\N{CJK UNIFIED IDEOGRAPH-96C4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\silva\AppData\Local\Temp\ipykernel_14268\4266876408.py:34: UserWarning: Glyph 20114 (\N{CJK UNIFIED IDEOGRAPH-4E92}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\silva\AppData\Local\Temp\ipykernel_14268\4266876408.py:34: UserWarning: Glyph 23089 (\N{CJK UNIFIED IDEOGRAPH-5A31}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\silva\.conda\envs\datavis\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# Hypothesen:
# ---
# 1. Haben Spiele mit höherer avg. Spielzeit auch bessere avg. Bewertungen?
# 2. Werden teuere Spiele besser bewertet und oder häufiger gespielt?
# 3. Was sind die aktuell grössten Genres basierend auf der Anzahl geschätzte Besitzer?
# 4. Ist das Genre mit grösstem Peak CCU (Concurrent Users) auch das aktuell grösste?
# 5. Lassen sich alte Spiele die häufig gespielt werden als aktuellere Games?

# %%
plt.scatter(df["Price"], df["Average playtime forever"])

# %%
df_new = df[(df['Price'] <= 400) & (df['Average playtime forever'] <= 10000)]
plt.scatter(df_new["Price"], df_new["Average playtime forever"])
